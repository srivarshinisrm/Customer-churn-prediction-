# %%
# !python.exe -m pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (26.0.1)

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (3.0.2)
# Requirement already satisfied: numpy>=2.3.3 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (2.4.4)

# %%
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wordcloud in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (1.9.6)
# Requirement already satisfied: numpy>=1.19.3 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from wordcloud) (2.4.4)
# Requirement already satisfied: pillow in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from wordcloud) (12.2.0)
# Requirement already satisfied: matplotlib in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from wordcloud) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib->wordcloud) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib->wordcloud) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib->wordcloud) (26.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib->wordcloud) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from scikit-learn) (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from scikit-learn) (3.6.0)

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from seaborn) (3.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from pandas>=1.2->seaborn) (2026.1)
# Requirement already satisfied: six>=1.5 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
# !pip install imbalanced-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imbalanced-learn in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (0.14.1)
# Requirement already satisfied: numpy<3,>=1.25.2 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from imbalanced-learn) (2.4.4)
# Requirement already satisfied: scipy<2,>=1.11.4 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from imbalanced-learn) (1.17.1)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from imbalanced-learn) (1.8.0)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from imbalanced-learn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from imbalanced-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from imbalanced-learn) (3.6.0)

# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (3.9.4)
# Requirement already satisfied: click in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from nltk) (8.3.2)
# Requirement already satisfied: joblib in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from nltk) (2026.4.4)
# Requirement already satisfied: tqdm in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from click->nltk) (0.4.6)

# %%
# !pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (3.2.0)
# Requirement already satisfied: numpy in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from xgboost) (2.4.4)
# Requirement already satisfied: scipy in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from xgboost) (1.17.1)

# %%
# !pip uninstall scikit-learn -y
# !pip install scikit-learn
# Out:
# Found existing installation: scikit-learn 1.8.0
# Uninstalling scikit-learn-1.8.0:
#   Successfully uninstalled scikit-learn-1.8.0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Using cached scikit_learn-1.8.0-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from scikit-learn) (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\sriva\AppData\Roaming\Python\Python314\site-packages (from scikit-learn) (3.6.0)
# Using cached scikit_learn-1.8.0-cp314-cp314-win_amd64.whl (8.1 MB)
# Installing collected packages: scikit-learn
# Successfully installed scikit-learn-1.8.0

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\sriva\AppData\Local\Programs\Python\Python311\python.exe

# %%
import sys
# !{sys.executable} -m pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn) (2.4.2)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn) (3.6.0)

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\sriva\AppData\Local\Programs\Python\Python311\python.exe

# %%
import sys
# !{sys.executable} -m pip install scikit-learn imbalanced-learn wordcloud nltk xgboost
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.8.0)
# Requirement already satisfied: imbalanced-learn in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.14.1)
# Requirement already satisfied: wordcloud in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.9.6)
# Requirement already satisfied: nltk in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (3.9.4)
# Requirement already satisfied: xgboost in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (3.2.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn) (2.4.2)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from imbalanced-learn) (0.1.5)
# Requirement already satisfied: pillow in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from wordcloud) (12.2.0)
# Requirement already satisfied: matplotlib in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from wordcloud) (3.10.8)
# Requirement already satisfied: click in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk) (2026.4.4)
# Requirement already satisfied: tqdm in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib->wordcloud) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib->wordcloud) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib->wordcloud) (26.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib->wordcloud) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
import sklearn
print("✅", sklearn.__version__)
# Out:
# ✅ 1.8.0

# %%
import sys
# !{sys.executable} -m pip install seaborn imbalanced-learn wordcloud nltk xgboost
# Out:
# Requirement already satisfied: seaborn in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.13.2)
# Requirement already satisfied: imbalanced-learn in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.14.1)
# Requirement already satisfied: wordcloud in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.9.6)
# Requirement already satisfied: nltk in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (3.9.4)
# Requirement already satisfied: xgboost in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (3.2.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from seaborn) (2.4.2)
# Requirement already satisfied: pandas>=1.2 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from seaborn) (3.0.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: scipy<2,>=1.11.4 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from imbalanced-learn) (1.17.1)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from imbalanced-learn) (1.8.0)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from imbalanced-learn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from imbalanced-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from imbalanced-learn) (3.6.0)
# Requirement already satisfied: pillow in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from wordcloud) (12.2.0)
# Requirement already satisfied: click in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk) (2026.4.4)
# Requirement already satisfied: tqdm in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Requirement already satisfied: colorama in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (from click->nltk) (0.4.6)

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in C:\Users\sriva\AppData\Local\Programs\Python\Python311\Lib\site-packages (26.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import seaborn as sns
import imblearn
import wordcloud
import nltk
import xgboost

print("✅ All libraries loaded successfully!")
print(f"Pandas: {pd.__version__}")
print(f"Scikit-learn: {sklearn.__version__}")
print(f"XGBoost: {xgboost.__version__}")
# Out:
# ✅ All libraries loaded successfully!
# Pandas: 3.0.0
# Scikit-learn: 1.8.0
# XGBoost: 3.2.0
